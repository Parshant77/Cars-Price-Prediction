# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
a=pd.read_csv('cars.csv')

# %%
a.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
a.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
a.describe()
# Out:
#         symboling       width      height  engine-size    city-mpg  \
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean     0.834146   65.907805   53.724878   126.907317   25.219512
# std      1.245307    2.145204    2.443522    41.642693    6.542142
# min     -2.000000   60.300000   47.800000    61.000000   13.000000
# 25%      0.000000   64.100000   52.000000    97.000000   19.000000
# 50%      1.000000   65.500000   54.100000   120.000000   24.000000
# 75%      2.000000   66.900000   55.500000   141.000000   30.000000
# max      3.000000   72.300000   59.800000   326.000000   49.000000
#
#        highway-mpg         price
# count   205.000000    205.000000
# mean     30.751220  13227.478049
# std       6.886443   7902.651615
# min      16.000000   5118.000000
# 25%      25.000000   7788.000000
# 50%      30.000000  10345.000000
# 75%      34.000000  16500.000000
# max      54.000000  45400.000000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
a['normalized-losses'].replace('?',np.nan,inplace=True)

# %%
a.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3               NaN  alfa-romero       gas  convertible
# 1          3               NaN  alfa-romero       gas  convertible
# 2          1               NaN  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
a['normalized-losses']=a['normalized-losses'].astype(float)

# %%
a.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
z=a['normalized-losses'].mean()
a['normalized-losses'].fillna(z,inplace=True)

# %%
a.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
a['horsepower'].replace('?',np.nan,inplace=True)

# %%
a['horsepower']=a['horsepower'].astype(float)

# %%
a.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
a.dropna(inplace=True)

# %%
a.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# # handle outliues

# %%
sns.boxplot(data=a,x='price')
plt.show()

# %%
a['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# mercury           1
# Name: make, dtype: int64

# %%
plt.figure(figsize=(7,7))
sns.boxplot(data=a,x='price',y='make')
plt.show()

# %%
a.loc[(a['make']=='toyota') & (a['price']>13000)]
# Out:
#      symboling  normalized-losses    make fuel-type   body-style drive-wheels  \
# 172          2              134.0  toyota       gas  convertible          rwd
# 178          3              197.0  toyota       gas    hatchback          rwd
# 179          3              197.0  toyota       gas    hatchback          rwd
# 180         -1               90.0  toyota       gas        sedan          rwd
# 181         -1              122.0  toyota       gas        wagon          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 172           front   65.6    53.0         ohc          146       116.0
# 178           front   67.7    52.0        dohc          171       161.0
# 179           front   67.7    52.0        dohc          171       161.0
# 180           front   66.5    54.1        dohc          171       156.0
# 181           front   66.5    54.1        dohc          161       156.0
#
#      city-mpg  highway-mpg  price
# ...

# %%
a.drop(index=[172,178,179,180,181],inplace=True)

# %%
plt.figure(figsize=(7,7))
sns.boxplot(data=a,x='price',y='make')
plt.show()

# %%
a.loc[(a['make']=='plymouth') & (a['price']>10000)]
# Out:
#      symboling  normalized-losses      make fuel-type body-style drive-wheels  \
# 124          3              122.0  plymouth       gas  hatchback          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 124           front   66.3    50.2         ohc          156       145.0
#
#      city-mpg  highway-mpg  price
# 124        19           24  12764

# %%
a.drop(index=[124],inplace=True)

# %%
a.loc[(a['make']=='mitsubishi') & (a['price']>13000)]
# Out:
#     symboling  normalized-losses        make fuel-type body-style  \
# 83          3              122.0  mitsubishi       gas  hatchback
# 84          3              122.0  mitsubishi       gas  hatchback
#
#    drive-wheels engine-location  width  height engine-type  engine-size  \
# 83          fwd           front   66.3    50.2         ohc          156
# 84          fwd           front   66.3    50.2         ohc          156
#
#     horsepower  city-mpg  highway-mpg  price
# 83       145.0        19           24  14869
# 84       145.0        19           24  14489

# %%
a.drop(index=[83,84],inplace=True)

# %%
a.loc[(a['make']=='isuzu') & (a['price']>20000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0              122.0  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 45           front   63.6    52.0         ohc           90        70.0
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
a.drop(index=[45],inplace=True)

# %%
a.loc[(a['make']=='honda') & (a['price']>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 41          0               85.0  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 41           front   65.2    54.1         ohc          110       101.0
#
#     city-mpg  highway-mpg  price
# 41        24           28  12945

# %%
a.drop(index=[41],inplace=True)

# %%
a.loc[(a['make']=='dodge') & (a['price']>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 29          3              145.0  dodge       gas  hatchback          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 29           front   66.3    50.2         ohc          156       145.0
#
#     city-mpg  highway-mpg  price
# 29        19           24  12964

# %%
a.drop(index=[29],inplace=True)

# %%
plt.figure(figsize=(9,7))
sns.boxplot(data=a,x='price',y='make')
plt.show()

# %% [markdown]
# # Encoding

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          192 non-null    int64
#  1   normalized-losses  192 non-null    float64
#  2   make               192 non-null    object
#  3   fuel-type          192 non-null    object
#  4   body-style         192 non-null    object
#  5   drive-wheels       192 non-null    object
#  6   engine-location    192 non-null    object
#  7   width              192 non-null    float64
#  8   height             192 non-null    float64
#  9   engine-type        192 non-null    object
#  10  engine-size        192 non-null    int64
#  11  horsepower         192 non-null    float64
#  12  city-mpg           192 non-null    int64
#  13  highway-mpg        192 non-null    int64
#  14  price              192 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %%
df_num=a.select_dtypes(['int','float'])

# %%
df_cat=a.select_dtypes(['object'])

# %%
df_num
# Out:
#      symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0            3              122.0   64.1    48.8          130       111.0
# 1            3              122.0   64.1    48.8          130       111.0
# 2            1              122.0   65.5    52.4          152       154.0
# 3            2              164.0   66.2    54.3          109       102.0
# 4            2              164.0   66.4    54.3          136       115.0
# ..         ...                ...    ...     ...          ...         ...
# 200         -1               95.0   68.9    55.5          141       114.0
# 201         -1               95.0   68.8    55.5          141       160.0
# 202         -1               95.0   68.9    55.5          173       134.0
# 203         -1               95.0   68.9    55.5          145       106.0
# 204         -1               95.0   68.9    55.5          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# ...

# %%
df_cat
# Out:
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          4wd           front
# ..           ...       ...          ...          ...             ...
# 200        volvo       gas        sedan          rwd           front
# 201        volvo       gas        sedan          rwd           front
# 202        volvo       gas        sedan          rwd           front
# 203        volvo    diesel        sedan          rwd           front
# 204        volvo       gas        sedan          rwd           front
#
#     engine-type
# 0          dohc
# 1          dohc
# 2          ohcv
# 3           ohc
# 4           ohc
# ..          ...
# ...

# %%
#import the model 
from sklearn.preprocessing import LabelEncoder
#init Labelencoding
le=LabelEncoder()
a['fuel-type']=le.fit_transform(a['fuel-type'])

# %%
for i in df_cat:
    le=LabelEncoder()
    df_cat[i]=le.fit_transform(df_cat[i])

# %%
df_cat[i]
# Out:
# 0      0
# 1      0
# 2      5
# 3      3
# 4      3
#       ..
# 200    3
# 201    3
# 202    5
# 203    3
# 204    3
# Name: engine-type, Length: 192, dtype: int32

# %%
df_cat
# Out:
#      make  fuel-type  body-style  drive-wheels  engine-location  engine-type
# 0       0          1           0             2                0            0
# 1       0          1           0             2                0            0
# 2       0          1           2             2                0            5
# 3       1          1           3             1                0            3
# 4       1          1           3             0                0            3
# ..    ...        ...         ...           ...              ...          ...
# 200    20          1           3             2                0            3
# 201    20          1           3             2                0            3
# 202    20          1           3             2                0            5
# 203    20          0           3             2                0            3
# 204    20          1           3             2                0            3
#
# [192 rows x 6 columns]

# %%
df3=pd.concat([df_cat,df_num],axis=1)

# %%
df3
# Out:
#      make  fuel-type  body-style  drive-wheels  engine-location  engine-type  \
# 0       0          1           0             2                0            0
# 1       0          1           0             2                0            0
# 2       0          1           2             2                0            5
# 3       1          1           3             1                0            3
# 4       1          1           3             0                0            3
# ..    ...        ...         ...           ...              ...          ...
# 200    20          1           3             2                0            3
# 201    20          1           3             2                0            3
# 202    20          1           3             2                0            5
# 203    20          0           3             2                0            3
# 204    20          1           3             2                0            3
#
# ...

# %% [markdown]
# # feature sacling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit_transform(a[['width']])
# Out:
# array([[-0.81378075],
#        [-0.81378075],
#        [-0.17567029],
#        [ 0.14338494],
#        [ 0.23454358],
#        [ 0.18896426],
#        [ 2.51350951],
#        [ 2.51350951],
#        [ 2.51350951],
#        [ 0.91823336],
#        [-0.49472552],
#        [-0.49472552],
#        [-0.49472552],
#        [-0.49472552],
#        [ 0.46244017],
#        [ 0.46244017],
#        [ 0.91823336],
#        [ 2.28561291],
#        [-2.54579486],
#        [-1.04167734],
#        [-1.04167734],
#        [-0.95051871],
#        [-0.95051871],
#        [-0.95051871],
#        [-0.95051871],
#        [-0.95051871],
#        [-0.95051871],
#        [-0.95051871],
#        [-0.58588416],
#        [-0.90493939],
#        [-0.90493939],
#        [-0.85936007],
#        [-0.85936007],
#        [-0.85936007],
#        [-0.85936007],
#        [-0.90493939],
#        [-0.31240825],
#        [-0.31240825],
#        [-0.31240825],
#        [-1.54304985],
#        [ 0.0522263 ],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mn=MinMaxScaler()
mn.fit_transform(a[['width']])
# Out:
# array([[0.31666667],
#        [0.31666667],
#        [0.43333333],
#        [0.49166667],
#        [0.50833333],
#        [0.5       ],
#        [0.925     ],
#        [0.925     ],
#        [0.925     ],
#        [0.63333333],
#        [0.375     ],
#        [0.375     ],
#        [0.375     ],
#        [0.375     ],
#        [0.55      ],
#        [0.55      ],
#        [0.63333333],
#        [0.88333333],
#        [0.        ],
#        [0.275     ],
#        [0.275     ],
#        [0.29166667],
#        [0.29166667],
#        [0.29166667],
#        [0.29166667],
#        [0.29166667],
#        [0.29166667],
#        [0.29166667],
#        [0.35833333],
#        [0.3       ],
#        [0.3       ],
#        [0.30833333],
#        [0.30833333],
#        [0.30833333],
#        [0.30833333],
#        [0.3       ],
#        [0.40833333],
#        [0.40833333],
#        [0.40833333],
#        [0.18333333],
#        [0.475     ],
#        [0.125     ],
#        [0.275     ],
# ...

# %%
#sns.pairplot(a)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               192 non-null    int32
#  1   fuel-type          192 non-null    int32
#  2   body-style         192 non-null    int32
#  3   drive-wheels       192 non-null    int32
#  4   engine-location    192 non-null    int32
#  5   engine-type        192 non-null    int32
#  6   symboling          192 non-null    int64
#  7   normalized-losses  192 non-null    float64
#  8   width              192 non-null    float64
#  9   height             192 non-null    float64
#  10  engine-size        192 non-null    int64
#  11  horsepower         192 non-null    float64
#  12  city-mpg           192 non-null    int64
#  13  highway-mpg        192 non-null    int64
#  14  price              192 non-null    int64
# dtypes: float64(4), int32(6), int64(5)
# memory usage: 19.5 KB

# %%
x=df3.iloc[:,:-1]
x
# Out:
#      make  fuel-type  body-style  drive-wheels  engine-location  engine-type  \
# 0       0          1           0             2                0            0
# 1       0          1           0             2                0            0
# 2       0          1           2             2                0            5
# 3       1          1           3             1                0            3
# 4       1          1           3             0                0            3
# ..    ...        ...         ...           ...              ...          ...
# 200    20          1           3             2                0            3
# 201    20          1           3             2                0            3
# 202    20          1           3             2                0            5
# 203    20          0           3             2                0            3
# 204    20          1           3             2                0            3
#
# ...

# %%
y=a['price']
y
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 192, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
ypred
# Out:
# array([30360.54926131, 29863.90130056, 14447.23720294,  9907.35656804,
#        15748.70099152, 13152.66791331, 33346.49144911, 10797.7971487 ,
#        16302.58216873, 10031.84104393,  9715.87349754, 13058.53531023,
#         3551.99379873, 25277.25045918, 16296.85103277, 24876.92615667,
#        14270.91803034,  7362.85724566,  5387.60049914,  8311.53409464,
#         9350.22179708, 16152.44500545, 20247.26553925, 15843.62204   ,
#        12704.87493632, 16328.6609878 ,  3664.70694979,  9667.19558921,
#        10002.66665023,  7188.70460854, 24219.46295959, 16547.76738758,
#        12704.87493632,  7562.16150749, 15378.54037285, 21467.60516767,
#        10712.56883929,  6016.39067301, 10337.05368753, 17557.90874131,
#         4454.88299143,  7745.38776991, 10796.623747  ,  8722.74897394,
#         8344.40734894,  9689.53806589, 14515.72865205, 12951.1733884 ,
#        10460.7120466 , 16793.83022724,  5453.14334593, 28103.98286158,
# ...

# %%
xtest
# Out:
#      make  fuel-type  body-style  drive-wheels  engine-location  engine-type  \
# 47      7          1           3             2                0            0
# 72      9          1           0             2                0            5
# 169    18          1           2             2                0            3
# 36      5          1           4             1                0            3
# 195    20          1           4             2                0            3
# 11      2          1           3             2                0            3
# 128    15          1           0             2                1            4
# 86     11          1           3             1                0            3
# 115    13          1           3             2                0            2
# 193    19          1           4             1                0            3
# 185    19          1           3             1                0            3
# ...

# %%
lr.intercept_
# Out:
# -40919.022659523354

# %%
lr.coef_
# Out:
# array([-1.57394217e+02, -7.70555055e+02, -6.84914491e+01,  1.50430823e+03,
#         1.34396003e+04,  1.42010201e+02,  3.54823385e+02, -9.40551130e-01,
#         4.56214788e+02,  3.64691983e+02,  1.02089013e+02, -1.30394095e+01,
#         5.03188223e+01, -2.80103852e+02])

# %%
pd.DataFrame(lr.coef_,x.columns)
# Out:
#                               0
# make                -157.394217
# fuel-type           -770.555055
# body-style           -68.491449
# drive-wheels        1504.308230
# engine-location    13439.600321
# engine-type          142.010201
# symboling            354.823385
# normalized-losses     -0.940551
# width                456.214788
# height               364.691983
# engine-size          102.089013
# horsepower           -13.039410
# city-mpg              50.318822
# highway-mpg         -280.103852

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
print(f"MAE={mean_absolute_error(ytest,ypred)}")
print(f"MSE={mean_squared_error(ytest,ypred)}")
print(f"SMAE={np.sqrt(mean_squared_error(ytest,ypred))}")
# Out:
# MAE=2658.3686058439507
# MSE=13790543.576403556
# SMAE=3713.5621142514306

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,ypred)
# Out:
# 0.831218229889261

# %%
import pickle
pickle.dump(lr,open('C:\\Itvedant\\Machin Learning\\project\\price_pred.pkl','wb'))

# %%
a.head()
# Out:
#    symboling  normalized-losses         make  fuel-type   body-style  \
# 0          3              122.0  alfa-romero          1  convertible
# 1          3              122.0  alfa-romero          1  convertible
# 2          1              122.0  alfa-romero          1    hatchback
# 3          2              164.0         audi          1        sedan
# 4          2              164.0         audi          1        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# ...
